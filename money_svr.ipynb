# %%
import tensorflow as tf
import pandas as pd
from sklearn.svm import LinearSVC
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
Money =pd.read_csv('../Downloads/kboall2.csv')
data1=Money['WAR']
data2=Money["WPA"]
label=Money["Salary"]
W1 = tf.Variable(tf.random_normal([1]), name = 'weight')
W2 = tf.Variable(tf.random_normal([1]), name = 'weight')
b = tf. Variable(tf.random_normal([1]), name='bias')
X1=tf.placeholder(tf.float32, shape=[None])
X2=tf.placeholder(tf.float32, shape=[None])
Y=tf.placeholder(tf.float32, shape=[None])

# %%
hypothesis = X1 * W1+X2 * W2 + b

# %%
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)

# %%
train=optimizer.minimize(cost)

# %%
sess=tf.Session()

# %%
sess.run(tf.global_variables_initializer())

# %%
for step in range(2001):
    cost_val, W1_val, W2_val, b_val, _= sess.run([cost, W1, W2, b, train],
                                       feed_dict={X1:data1,X2: data2,Y:label})
    if step % 20 == 0:
        print(step,cost_val,W1_val,W2_val, b_val)
# Out:
# 0 3883332000.0 [2217.7285] [689.4503] [913.2613]
# 20 1722326400.0 [14110.866] [-1160.2747] [9571.531]
# 40 1591431200.0 [15189.889] [-3839.535] [13478.25]
# 60 1552269400.0 [15169.516] [-4718.2036] [16044.836]
# 80 1533108900.0 [14811.745] [-4853.387] [17934.828]
# 100 1520649500.0 [14365.36] [-4713.6665] [19427.875]
# 120 1511758300.0 [13924.908] [-4488.343] [20655.838]
# 140 1505261700.0 [13523.327] [-4251.546] [21687.504]
# 160 1500488000.0 [13169.024] [-4030.4587] [22563.584]
# 180 1496975700.0 [12861.027] [-3833.3882] [23311.49]
# 200 1494390800.0 [12595.128] [-3661.2666] [23951.6]
# 220 1492488200.0 [12366.323] [-3512.3428] [24500.133]
# 240 1491088000.0 [12169.74] [-3384.0583] [24970.477]
# 260 1490057300.0 [12000.971] [-3273.786] [25373.887]
# 280 1489298800.0 [11856.133] [-3179.092] [25719.936]
# 300 1488740200.0 [11731.853] [-3097.8164] [26016.8]
# 320 1488329200.0 [11625.221] [-3028.073] [26271.486]
# 340 1488026900.0 [11533.734] [-2968.2314] [26489.984]
# ...

# %%
y=10981.335*data1-2606.882*data2+27809.225

# %%
y
# Out:
# 0      69133.89455
# 1      65993.61196
# 2      64332.09251
# 3      65587.31241
# 4      55975.47634
# 5      62541.57592
# 6      59563.24432
# 7      56363.66449
# 8      55444.09619
# 9      57828.10843
# 10     44897.69914
# 11     52130.51190
# 12     47248.48296
# 13     43708.38694
# 14     42608.63191
# 15     39736.19712
# 16     35183.60823
# 17     39697.43063
# 18     39815.07706
# 19     40627.12702
# 20     39400.27095
# 21     36179.48689
# 22     34698.15417
# 23     36289.02567
# 24     39119.45091
# 25     33591.23954
# 26     32969.50440
# 27     36920.88890
# 28     29785.86530
# 29     30797.01121
#           ...
# 152    56686.21951
# 153    38258.65660
# 154    43776.46531
# 155    36483.40726
# 156    36107.36764
# 157    33865.84803
# 158    31023.92185
# 159    21487.32375
# 160    96672.87268
# 161    80372.27578
# 162    81310.47873
# 163    71370.27500
# 164    64932.07428
# 165    46101.72945
# 166    49259.97321
# 167    42761.52720
# ...
